# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import torch

print("✅ Ultralytics YOLOv8 installed successfully!")
print("🔥 Using GPU:", torch.cuda.is_available())
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/ultralytics-thop/
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.4 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Ultralytics YOLOv8 installed successfully!
# 🔥 Using GPU: True

# %%
import os
import random
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import torch
import yaml
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Load model
model = YOLO('/content/drive/MyDrive/Yolov11 Result/customizedYolov11.yaml')

# Train model
results = model.train(
    data="/content/drive/MyDrive/temp/data.yaml",
    epochs=100,
    batch=16,
    name="cavity_yolov11m",
    lr0=0.0001,           # learning rate
    optimizer='Adam',
    patience=30,         # early stopping if no improvement
    weight_decay=0.0005,
    project="/content/drive/MyDrive/Yolov11 Result",# save results to Drive

)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Load your last trained model
model = YOLO('/content/drive/MyDrive/Yolov11 Result/cavity_yolov11m/weights/last.pt')

# Resume training from where you left off
model.train(
    data='/content/drive/MyDrive/temp/data.yaml',  # path to your data.yaml file
    epochs=100,          # total number of epochs you want
    resume=True          # important flag to resume
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your last trained model
model = YOLO('/content/drive/MyDrive/Yolov11 Result/cavity_yolov11m/weights/last.pt')

# Resume training from where you left off
model.train(
    data='/content/drive/MyDrive/temp/data.yaml',  # path to your data.yaml file
    epochs=100,          # total number of epochs you want
    resume=True          # important flag to resume
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# ✅ Load your previously trained best model
model = YOLO("/content/drive/MyDrive/Yolov11 Result/cavity_yolov11m/weights/best.pt")

# ✅ Fine-tune (continue training with small LR)
results = model.train(
    data="/content/drive/MyDrive/temp/data.yaml",  # your dataset YAML
    epochs=100,             # add 50 more epochs (can increase if improving)
    imgsz=1024,            # higher resolution for dental images
    batch=8,               # adjust per GPU memory
    lr0=0.00005,           # very small LR for fine-tuning
    optimizer="Adam",
    weight_decay=0.0005,
    patience=15,           # stop early if no improvement
    project="/content/drive/MyDrive/Yolov11 Result",
    name="cavity_yolov11m_finetuned",
    pretrained=True        # continue from your trained weights
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your last trained model
model = YOLO('/content/drive/MyDrive/Yolov11 Result/cavity_yolov11m_finetuned/weights/last.pt')

# Resume training from where you left off
model.train(
    data='/content/drive/MyDrive/temp/data.yaml',  # path to your data.yaml file
    epochs=100,          # total number of epochs you want
    resume=True          # important flag to resume
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your last trained model
model = YOLO('/content/drive/MyDrive/Yolov11 Result/cavity_yolov11m_finetuned/weights/last.pt')

# Resume training from where you left off
model.train(
    data='/content/drive/MyDrive/temp/data.yaml',  # path to your data.yaml file
    epochs=100,          # total number of epochs you want
    resume=True          # important flag to resume
)
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
